# %%
import os
import requests
import json

import pycountry

from datetime import datetime, timedelta

import pandas as pd

from bs4 import BeautifulSoup

# %%
from api_query_setup import QuerySetup

# %%
## get TR AuthToken

def get_authtoken(username, password):
    '''Tries to load cached authentification token and renews it if necessary.'''
    if os.path.isfile('authtoken.cache'):
        # read cached authtoken
        with open('authtoken.cache', 'r') as f:
            authToken = f.read()
    else: 
        authToken = None
    
    if authToken is not None:
        # check validity of authToken
        url = f'http://rmb.reuters.com/rmd/rest/json/channels?token={authToken}&format=json'
        response = requests.get(url) # 
        json.loads(response.text)
        if response == '<Response [403]>':
            authToken = None
    
    if authToken is None:
        print('Renewing AuthToken...')
        auth_url = f"https://commerce.reuters.com/rmd/rest/xml/login?username={username}&password={password}&format=json"
        response = requests.get(auth_url)
        authToken = json.loads(response.text).get('authToken').get('authToken')
        with open('authtoken.cache', 'w') as f:
            f.write(authToken)

    return authToken
    

username = 'HackAPI3'
password = 'xfzzzEOBEJrmWpi'

authToken = get_authtoken(username, password)

print(authToken)
# Out:
# 3SDnXO+c5NcIo45KY4ZrT5Lw89ntAckI81kIX5wuiTI=

# %% [markdown]
# ## Retrieve country codes for relevant countries
# ### (according to https://www.dol.gov/agencies/ilab/reports/child-labor/list-of-goods)

# %%
# load TR country codes dataframe

tr_country_file = '../Data/TR_API_files/tr_country_codes_normalized.tsv'

#cc_df = pd.read_csv(tr_country_file, sep='\t', dtype='str')
cc_df = pd.read_csv(tr_country_file, sep='\t', dtype=object, na_filter=False)

# retrieve country code mapping as dictionary

cc_mapping = {k:v for k,v in zip(cc_df.country_name, cc_df.country_code)}
cc_mapping_long = {k:v for k,v in zip(cc_df.country_name_long, cc_df.country_code) if str(k) != 'nan'}

cc_mapping.update(cc_mapping_long)

num_mappings = len(cc_mapping)

print(f'{len(cc_mapping)} mapping instances found.')


# retrieve country code area mappings

area_mappings = {k:v for k,v in zip(cc_df.country_code, cc_df.area)}
# Out:
# 492 mapping instances found.

# %%
# extract list of relevant country codes from GSI dataset

country_file = '../Data/ListofGoodsExcel.tsv'

country_goods_df = pd.read_csv(country_file)

countries = country_goods_df.country

countries_df = pd.DataFrame(countries)

countries_df['country_code'] = countries_df.country.apply(lambda x: cc_mapping.get(x))

# check that all countries have been mapped
assert countries_df[countries_df.country_code.isna()].shape[0] == 0

relevant_country_codes = countries_df.country_code.unique().tolist()

# %%
# reverse mapping from country codes to GSI country names

cc_mapping_reverse = {v:k for k,v in cc_mapping.items() if k in countries_df.country.unique().tolist()}

# %%
# mapping of country code to country for newer (normalized) country names (e.g. Myanmar instead of Burma)

country_file_normalized = '../Data/ListofGoodsExcel_normalized.tsv'

countries_normalized = pd.read_csv(country_file_normalized).country.unique()

cc_mapping_reverse_normalized = {v:k for k,v in cc_mapping.items() if k in countries_normalized}

# %% [markdown]
# ### Configure the Query
#
# - **keywords**: human trafficking, slavery, child labour, child labor, forced labor, force labour, debt boundage
# - **countries**: all countries specified by the GSI as being involved in human trafficking in good production (according to the ListofGoods as defined above)
# - **language**: English is default (can be expanded to more languagues but for simplicity, we currently only consider English)
# - **daterange**: The TR API sadly only allows for one month
# - **media type**: Text

# %%
query_terms = ['human trafficking',
            'slavery',
            'child labour',
            'child labor',
            'forced labor',
            'force labour',
            'debt boundage']

# %%
# initiate query setup module

q_setup = QuerySetup(authToken, query_terms=query_terms, geography=relevant_country_codes)

# %%
# get the query url from the query setup module

url = q_setup.query_url()
url
# Out:
# 'http://rmb.reuters.com/rmd/rest/json/search?q=main:("human trafficking" OR "slavery" OR "child labour" OR "child labor" OR "forced labor" OR "force labour" OR "debt boundage")&mediaType=T&dateRange=2018.11.03-2019.11.03&language=en&geography=AF&geography=AO&geography=AR&geography=AZ&geography=BD&geography=BZ&geography=BJ&geography=BO&geography=BR&geography=BF&geography=MM&geography=KH&geography=CM&geography=CF&geography=TD&geography=CN&geography=CO&geography=CR&geography=CI&geography=CD&geography=DO&geography=EC&geography=EG&geography=SV&geography=SZ&geography=ET&geography=GH&geography=GT&geography=GN&geography=HN&geography=IN&geography=ID&geography=IR&geography=KZ&geography=KE&geography=KG&geography=LB&geography=LS&geography=LR&geography=MG&geography=MW&geography=MY&geography=ML&geography=MR&geography=MX&geography=MN&geography=MZ&geography=NA&geography=NP&geography=NI&geography=NE&geography=NG&geography=KP&geography=PK&geography=PA&geography=PY&geography=PE&geography=PH&geography=RU&geography=RW&geography=SN&geography=SL&geography=SS&geography=SD&geography=SR&geography=TJ&geography=TZ&geography=TH&geography=TR&geography=TM&geography=UG&geography=UA&geography=UZ&geography=VN&geography=YE&geography=ZM&limit=1000&token=3SDnXO+c5NcIo45KY4ZrT5Lw89ntAckI81kIX5wuiTI='

# %%
# get results as json

response = requests.get(url)
print(response)
response_text = response.text
t_results = json.loads(response_text)
# Out:
# <Response [200]>

# %%
t_results
# Out:
# {'results': {'result': [{'id': 'tag:reuters.com,2019:newsml_L3N27I00W:391219080',
#     'guid': 'tag:reuters.com,2019:newsml_L3N27I00W',
#     'version': 391219080,
#     'dateCreated': 1572659257000,
#     'slug': 'BRITAIN-BODIES/VIETNAM',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Vietnam says human traffickers must be strictly dealt with',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['VN', 'BE', 'GB', 'CN', 'BG'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572659267216,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['ZZ',
#      'C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'DNP',
#      'M',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'SI',
#      'Z',
#      'REULB',
#      'RBN',
#      'PSC',
#      'LBY',
#      'ZD',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'UKI',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'AFA'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572659267216,
#     'channelIds': [76637,
#      63683,
#      37917,
#      26786,
#      144993,
#      626,
#      68932,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      161681,
#      57606,
#      154815,
#      180027,
#      63675,
#      63699,
#      75332,
#      46622,
#      159011,
#      583,
#      63667,
#      164607,
#      150029,
#      76633,
#      63685,
#      31396,
#      644,
#      76630,
#      63646,
#      27216,
#      27199,
#      44352,
#      211865,
#      180029,
#      158991,
#      20483,
#      142441,
#      63708,
#      672,
#      195519,
#      610,
#      648,
#      635,
#      62870,
#      22283,
#      159015,
#      141803,
#      23927,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      23926,
#      661,
#      565,
#      601,
#      118201,
#      31397,
#      63669,
#      22307,
#      2213,
#      63643,
#      127689,
#      176419,
#      634,
#      31377,
#      68945,
#      34327,
#      191903,
#      564,
#      127687,
#      22807,
#      180031,
#      63655,
#      70595,
#      30480,
#      63709,
#      554]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27H5Q0:447177668',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H5Q0',
#     'version': 447177668,
#     'dateCreated': 1572646886000,
#     'slug': 'BRAZIL-HUMAN TRAFFICKING/ (TV)',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': "Brazil police arrest man said to be one of world's most prolific human traffickers",
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['BR', 'BD', 'MX', 'AF', 'IN', 'US'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572646890383,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'SNS',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572646890383,
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      176417,
#      31386,
#      63692,
#      22321,
#      154815,
#      31371,
#      75332,
#      651,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      31376,
#      63685,
#      63698,
#      644,
#      182977,
#      211865,
#      158991,
#      20483,
#      142441,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      31374,
#      118201,
#      2213,
#      127689,
#      176419,
#      634,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_KBN1XB3XS:6',
#     'guid': 'tag:reuters.com,2019:newsml_KBN1XB3XS',
#     'version': 6,
#     'dateCreated': 1572640591000,
#     'slug': 'UK-BRITAIN-BODIES',
#     'author': 'By Amanda Ferguson',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Second man charged over UK truck deaths, victims now thought to be Vietnamese',
#     'mediaType': 'T',
#     'priority': 4,
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG', 'IND'],
#     'channels': ['TRn222'],
#     'indexTimestamp': 1572640594477,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['NOINSKM',
#      'OUKDNM',
#      'NOINWDM',
#      'ORTAK',
#      'OUKWDM',
#      'OUKTPM',
#      'ORTOA'],
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'internalReceivedDate': 1572640594477,
#     'channelIds': [23276,
#      83733,
#      22849,
#      25437,
#      176625,
#      23274,
#      149055,
#      176631,
#      24244,
#      153071,
#      176461,
#      25411,
#      24237,
#      24242,
#      176629]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27H2WN:1498332260',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H2WN',
#     'version': 1498332260,
#     'dateCreated': 1572640534000,
#     'slug': 'BRITAIN-BODIES/ (UPDATE 3, PIX, TV)',
#     'author': 'By Amanda Ferguson',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'UPDATE 3-Second man charged over UK truck deaths, victims now thought to be Vietnamese',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572640540811,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'UKI',
#      'RNP',
#      'RWSA',
#      'SI',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U',
#      'sic:XBSUM'],
#     'internalReceivedDate': 1572640540811,
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      154815,
#      63699,
#      75332,
#      23754,
#      46622,
#      159011,
#      583,
#      63667,
#      167293,
#      150029,
#      22802,
#      63685,
#      31396,
#      644,
#      211865,
#      158991,
#      142441,
#      63708,
#      648,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      23926,
#      118201,
#      31397,
#      22307,
#      2213,
#      127689,
#      170645,
#      176419,
#      634,
#      31377,
#      68945,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2:1099731627',
#     'guid': 'tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2',
#     'version': 1099731627,
#     'dateCreated': 1572615643000,
#     'slug': 'NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTER AND HUMAN TRAFFI',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTER AND HUMAN TRAFFICKING OFFENCES  IN RELATION TO 39 DEATHS IN UK TRUCK -  POLICE',
#     'mediaType': 'T',
#     'priority': 1,
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572615647562,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['ZZ',
#      'C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'M',
#      'ABN',
#      'GNS',
#      'O',
#      'CSA',
#      'U',
#      'Z',
#      'REULB',
#      'RBN',
#      'LBY',
#      'ZD',
#      'SOF',
#      'RWS',
#      'UCDPTEST',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'REUEB',
#      'AFA'],
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:N'],
#     'internalReceivedDate': 1572615647562,
#     'channelIds': [37917,
#      626,
#      176417,
#      34325,
#      63398,
#      63411,
#      57606,
#      63393,
#      63438,
#      63424,
#      583,
#      539,
#      584,
#      63447,
#      63446,
#      644,
#      211865,
#      20483,
#      142441,
#      672,
#      610,
#      63436,
#      561,
#      661,
#      565,
#      63462,
#      601,
#      118201,
#      2213,
#      127689,
#      176419,
#      634,
#      63430,
#      34327,
#      62871,
#      127687,
#      142045,
#      554]},
#    {'id': 'tag:reuters.com,2019:newsml_L3N27E1H0:518279271',
#     'guid': 'tag:reuters.com,2019:newsml_L3N27E1H0',
#     'version': 518279271,
#     'dateCreated': 1572612751000,
#     'slug': 'BRITAIN-BODIES/VIETNAM (URGENT)',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Vietnam arrests two people, questioning others over UK truck deaths -statement',
#     'mediaType': 'T',
#     'priority': 2,
#     'geography': ['VN', 'BE', 'GB', 'CN', 'BG'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572612756740,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'DNP',
#      'M',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'SI',
#      'Z',
#      'REULB',
#      'RBN',
#      'PSC',
#      'LBY',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'UKI',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'AFA'],
#     'signal': ['sig:update',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'internalReceivedDate': 1572612756740,
#     'channelIds': [76637,
#      63683,
#      37917,
#      26786,
#      144993,
#      626,
#      68932,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      161681,
#      57606,
#      154815,
#      180027,
#      63675,
#      63699,
#      75332,
#      46622,
#      159011,
#      583,
#      63667,
#      164607,
#      150029,
#      76633,
#      63685,
#      31396,
#      644,
#      76630,
#      63646,
#      27216,
#      27199,
#      44352,
#      211865,
#      180029,
#      158991,
#      20483,
#      142441,
#      63708,
#      672,
#      195519,
#      610,
#      648,
#      635,
#      62870,
#      22283,
#      159015,
#      141803,
#      23927,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      23926,
#      661,
#      565,
#      601,
#      118201,
#      31397,
#      63669,
#      22307,
#      2213,
#      63643,
#      127689,
#      176419,
#      634,
#      31377,
#      68945,
#      34327,
#      191903,
#      564,
#      127687,
#      22807,
#      180031,
#      63655,
#      70595,
#      30480,
#      63709,
#      554]},
#    {'id': 'tag:reuters.com,2019:newsml_L9N26H01Q:845204606',
#     'guid': 'tag:reuters.com,2019:newsml_L9N26H01Q',
#     'version': 845204606,
#     'dateCreated': 1572606114000,
#     'slug': 'BRITAIN-BODIES/ (URGENT, TV)',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'UK police appeal for two brothers from N.Ireland to hand themselves in over truck deaths',
#     'mediaType': 'T',
#     'priority': 2,
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572606119796,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['NAT',
#      'PTD',
#      'C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'DNP',
#      'M',
#      'ABN',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'SI',
#      'Z',
#      'REULB',
#      'RBN',
#      'PSC',
#      'LBY',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'UKI',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'PEN',
#      'PCM',
#      'AFA'],
#     'signal': ['sig:update',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'internalReceivedDate': 1572606119796,
#     'channelIds': [76637,
#      63683,
#      37917,
#      26786,
#      619,
#      144993,
#      626,
#      68932,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      623,
#      57606,
#      154815,
#      180027,
#      63675,
#      63699,
#      75332,
#      46622,
#      605,
#      159011,
#      583,
#      63667,
#      539,
#      164607,
#      167293,
#      150029,
#      22802,
#      76633,
#      63685,
#      31396,
#      644,
#      621,
#      76630,
#      63646,
#      27216,
#      27199,
#      44352,
#      211865,
#      180029,
#      158991,
#      20483,
#      142441,
#      63708,
#      672,
#      195519,
#      610,
#      648,
#      635,
#      62870,
#      22283,
#      159015,
#      141803,
#      23927,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      23926,
#      661,
#      565,
#      601,
#      118201,
#      31397,
#      63669,
#      22307,
#      2213,
#      63643,
#      127689,
#      170645,
#      63676,
#      176419,
#      634,
#      31377,
#      68945,
#      34327,
#      191903,
#      564,
#      127687,
#      22807,
#      180031,
#      63655,
#      70595,
#      30480,
#      63709,
#      554]},
#    {'id': 'tag:reuters.com,2019:newsml_L3N27G4K4:110591051',
#     'guid': 'tag:reuters.com,2019:newsml_L3N27G4K4',
#     'version': 110591051,
#     'dateCreated': 1572602251000,
#     'slug': 'THAILAND-TRAFFICKING/',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Thai court increases prison time for officials in Rohingya trafficking case',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['MM', 'TH', 'BD'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572602255727,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'DNP',
#      'M',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'SI',
#      'REULB',
#      'RBN',
#      'PSC',
#      'LBY',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'OIL',
#      'RWSA',
#      'AFA'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572602255727,
#     'channelIds': [37917,
#      144993,
#      626,
#      159003,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      57606,
#      154815,
#      180027,
#      63675,
#      63699,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      22798,
#      150029,
#      31376,
#      76633,
#      63685,
#      644,
#      31395,
#      182977,
#      63646,
#      27199,
#      44352,
#      211865,
#      180029,
#      158991,
#      142441,
#      610,
#      648,
#      635,
#      62870,
#      22283,
#      159015,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      661,
#      565,
#      601,
#      118201,
#      63669,
#      2213,
#      68945,
#      34327,
#      191903,
#      564,
#      180031,
#      63655,
#      70595,
#      30480,
#      63709,
#      554]},
#    {'id': 'tag:reuters.com,2019:newsml_L3N27G2IU:1222774372',
#     'guid': 'tag:reuters.com,2019:newsml_L3N27G2IU',
#     'version': 1222774372,
#     'dateCreated': 1572599941000,
#     'slug': 'ASIA-FOREST/PALMOIL',
#     'author': 'By Michael Taylor, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Palm oil giants double down on deforestation with new radar system',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['MY', 'US', 'ID'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572599946676,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572599946676,
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      55889,
#      27217,
#      154815,
#      23929,
#      211145,
#      22791,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      167293,
#      150029,
#      27212,
#      22802,
#      204119,
#      26789,
#      63685,
#      644,
#      182977,
#      170643,
#      23751,
#      27216,
#      211865,
#      142441,
#      195519,
#      635,
#      22283,
#      159015,
#      26780,
#      23927,
#      41078,
#      31388,
#      118201,
#      31387,
#      162059,
#      26788,
#      2213,
#      127689,
#      170645,
#      634,
#      187915,
#      66631,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_L3N27G291:4890607',
#     'guid': 'tag:reuters.com,2019:newsml_L3N27G291',
#     'version': 4890607,
#     'dateCreated': 1572517658000,
#     'slug': 'GLOBAL-FORESTS/EMISSIONS',
#     'author': 'By Michael Taylor, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Carbon emissions from tropical forest loss underestimated, scientists say',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['BR', 'CD', 'ID', 'AU', 'US'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572517663891,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'AFN',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572517663891,
#     'channelIds': [63683,
#      23925,
#      542,
#      37917,
#      26786,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      22800,
#      55889,
#      154815,
#      23929,
#      27253,
#      22170,
#      31371,
#      70666,
#      211145,
#      22791,
#      75332,
#      29598,
#      23754,
#      63633,
#      159011,
#      583,
#      63667,
#      167293,
#      150029,
#      157307,
#      22802,
#      204119,
#      63685,
#      644,
#      182977,
#      170643,
#      23751,
#      27216,
#      211865,
#      158991,
#      142441,
#      195519,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      26780,
#      23927,
#      41078,
#      118201,
#      31387,
#      162059,
#      2213,
#      127689,
#      170645,
#      634,
#      66631,
#      564,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27E30I:55370042',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27E30I',
#     'version': 55370042,
#     'dateCreated': 1572483661000,
#     'slug': 'LANDRIGHTS-HOUSING/HOMELESSNESS (FACTBOX)',
#     'author': 'By Umberto Bacchi, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': "FACTBOX-Cages, pods and containers: 8 homes highlighting cities' housing strains",
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['GB', 'CN', 'FR', 'US', 'ES'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572483667624,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'RLF',
#      'GNS',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['sic:CPX', 'prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572483667624,
#     'channelIds': [63683,
#      37917,
#      626,
#      63692,
#      22321,
#      131355,
#      55889,
#      23325,
#      75332,
#      154257,
#      583,
#      63685,
#      644,
#      211865,
#      142441,
#      22283,
#      41078,
#      118201,
#      2213,
#      63686,
#      127689,
#      24466,
#      634,
#      633,
#      66631,
#      127687,
#      63655,
#      70595]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27E22N:791291950',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27E22N',
#     'version': 791291950,
#     'dateCreated': 1572483600000,
#     'slug': 'THAILAND-FOOD/CHEF (INTERVIEW, PIX)',
#     'author': 'By Nanchanok Wongsamuth, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'INTERVIEW -Thai chef aims to turn insect eating into fine dining',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['TH'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572483604971,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['CSA',
#      'PSC',
#      'UCDPTEST',
#      'LBY',
#      'TRFDN',
#      'RWSA',
#      'G',
#      'REULB',
#      'AFA',
#      'GNS',
#      'RWS',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572483604971,
#     'channelIds': [37917,
#      626,
#      63692,
#      22321,
#      55889,
#      75332,
#      583,
#      63685,
#      644,
#      211865,
#      142441,
#      22283,
#      41078,
#      118201,
#      2213,
#      66631,
#      63655,
#      70595]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N24A00L:1250137644',
#     'guid': 'tag:reuters.com,2019:newsml_L8N24A00L',
#     'version': 1250137644,
#     'dateCreated': 1572480060000,
#     'slug': 'INDONESIA-WOMEN/MARRIAGE (FEATURE, PIX)',
#     'author': 'By Beh Lih Yi, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': "FEATURE -In Indonesia, 'bride kidnapping' tradition fuels child marriage despite new ban",
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['ID'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572480063980,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'SNS',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572480063980,
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      22800,
#      75332,
#      651,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      204119,
#      63685,
#      63698,
#      644,
#      182977,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      118201,
#      31387,
#      2213,
#      634,
#      47543,
#      191903,
#      564,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27F0PN:18574452',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27F0PN',
#     'version': 18574452,
#     'dateCreated': 1572465091000,
#     'slug': 'BANGLADESH-MIGRANTS/WOMEN',
#     'author': 'By Naimul Karim, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Abused Bangladeshi housemaids struggle for justice at home',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['BD', 'SA'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572465094790,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'SNS',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572465094790,
#     'channelIds': [37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      22800,
#      55889,
#      154815,
#      162061,
#      75332,
#      23754,
#      651,
#      159011,
#      583,
#      63667,
#      22798,
#      150029,
#      31376,
#      204119,
#      63685,
#      63698,
#      644,
#      182977,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      159015,
#      41078,
#      118201,
#      2213,
#      127689,
#      47543,
#      66631,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480,
#      31417]},
#    {'id': 'tag:reuters.com,2019:newsml_KBN1X92CO:3',
#     'guid': 'tag:reuters.com,2019:newsml_KBN1X92CO',
#     'version': 3,
#     'dateCreated': 1572464889000,
#     'slug': 'US-MIDEAST-CRISIS-BAGHDADI-MURAD',
#     'author': 'By Michelle Nichols',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'After Baghdadi death, Nobel laureate Nadia Murad asks: What about the rest?',
#     'mediaType': 'T',
#     'priority': 4,
#     'geography': ['RU', 'SY', 'IQ', 'IR', 'GB', 'IND', 'TR', 'US'],
#     'channels': ['FES376'],
#     'indexTimestamp': 1572464892424,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['OUSWDM', 'OCATPM', 'RTRFLN', 'OUSTPM', 'OUS12'],
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'internalReceivedDate': 1572464892424,
#     'channelIds': [176647,
#      176649,
#      56668,
#      62030,
#      150629,
#      65819,
#      65820,
#      24218,
#      24217,
#      25532]},
#    {'id': 'tag:reuters.com,2019:newsml_L2N27F1DR:253532727',
#     'guid': 'tag:reuters.com,2019:newsml_L2N27F1DR',
#     'version': 253532727,
#     'dateCreated': 1572462076000,
#     'slug': 'MIDEAST-CRISIS/BAGHDADI-MURAD (TV, PIX)',
#     'author': 'By Michelle Nichols',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'After Baghdadi death, Nobel laureate Nadia Murad asks: What about the rest?',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['RU', 'SY', 'IQ', 'IR', 'GB', 'TR', 'US'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572462081626,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'GBN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572462081626,
#     'channelIds': [63683,
#      37917,
#      22390,
#      144993,
#      626,
#      159003,
#      176417,
#      63692,
#      22321,
#      22800,
#      154815,
#      31407,
#      75332,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      204119,
#      63685,
#      644,
#      182977,
#      170643,
#      211865,
#      158991,
#      20483,
#      142441,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      23926,
#      31410,
#      118201,
#      2213,
#      127689,
#      30482,
#      176419,
#      634,
#      47543,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480,
#      588]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27F8CX:965671983',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27F8CX',
#     'version': 965671983,
#     'dateCreated': 1572460199000,
#     'slug': 'BELGIUM-MIGRANTS/ (UPDATE 1)',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'UPDATE 1-Police find 12 migrants alive in refrigerated truck in Belgium',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['SD', 'BE', 'GB', 'SY'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572460204195,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'UKI',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572460204195,
#     'channelIds': [63683,
#      37917,
#      26786,
#      144993,
#      626,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      154815,
#      75332,
#      159011,
#      583,
#      63667,
#      164607,
#      150029,
#      63685,
#      644,
#      182977,
#      27216,
#      211865,
#      158991,
#      20483,
#      142441,
#      63708,
#      195519,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      141803,
#      41078,
#      118201,
#      22307,
#      2213,
#      127689,
#      170645,
#      176419,
#      634,
#      191903,
#      564,
#      127687,
#      22807,
#      63655,
#      70595]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27F6PC:978044544',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27F6PC',
#     'version': 978044544,
#     'dateCreated': 1572458878000,
#     'slug': 'FACEBOOK-INDIA/CONTENT',
#     'author': 'By Roli Srivastava, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': "Facebook a 'megaphone for hate' against Indian minorities",
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['IN'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572458881320,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'SNS',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572458881320,
#     'channelIds': [37917,
#      144993,
#      626,
#      159003,
#      31386,
#      63692,
#      22321,
#      131355,
#      55889,
#      154815,
#      75332,
#      651,
#      159011,
#      583,
#      63667,
#      150029,
#      204119,
#      63685,
#      63698,
#      644,
#      182977,
#      170643,
#      158991,
#      142441,
#      635,
#      22283,
#      159015,
#      41078,
#      118201,
#      2213,
#      66631,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27F761:1777485889',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27F761',
#     'version': 1777485889,
#     'dateCreated': 1572458772000,
#     'slug': 'SENEGAL-TRAFFICKING/',
#     'author': 'By Nellie Peyton, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Senegal launches online database to track the traffickers',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['SN'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572458777771,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'AFN',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572458777771,
#     'channelIds': [140915,
#      542,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      55889,
#      27217,
#      154815,
#      70666,
#      75332,
#      29598,
#      46622,
#      63633,
#      159011,
#      583,
#      63667,
#      150029,
#      26789,
#      63685,
#      644,
#      182977,
#      170643,
#      211865,
#      158991,
#      142441,
#      195519,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      23927,
#      41078,
#      118201,
#      2213,
#      187915,
#      66631,
#      191903,
#      564,
#      63655,
#      70595]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27E66P:2016649738',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27E66P',
#     'version': 2016649738,
#     'dateCreated': 1572458072000,
#     'slug': 'GERMANY-BERLINWALL/STASI LOVE STORY (TV, PIX)',
#     'author': 'By Tanja Daube and Michelle Martin',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'The spy who loved me? West German recalls Stasi manipulation, imprisonment',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['DE', 'RU', 'GB', 'FR', 'US'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572458078520,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'sic:XBSUM',
#      'edStat:N'],
#     'internalReceivedDate': 1572458078520,
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      176417,
#      63692,
#      22321,
#      27217,
#      154815,
#      162061,
#      75332,
#      154257,
#      159011,
#      583,
#      63667,
#      150029,
#      153673,
#      63685,
#      49344,
#      644,
#      182977,
#      26561,
#      170643,
#      142441,
#      195519,
#      635,
#      159015,
#      141803,
#      41078,
#      27066,
#      26781,
#      118201,
#      2213,
#      127689,
#      30482,
#      37672,
#      176419,
#      634,
#      187915,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27D5Q6:2074450467',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27D5Q6',
#     'version': 2074450467,
#     'dateCreated': 1572427823000,
#     'slug': 'BRITAIN-BODIES/NAILBARS',
#     'author': 'By Emma Batha, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'REFILE-UK truck deaths reignite calls to tackle nail bar slavery',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['VN', 'GB'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572427829175,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'UKI',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT',
#      'pmt:text',
#      'sig:correction',
#      'source:ids',
#      'edStat:U'],
#     'internalReceivedDate': 1572427829175,
#     'channelIds': [37917,
#      144993,
#      626,
#      159003,
#      662,
#      63692,
#      22321,
#      131355,
#      55889,
#      154815,
#      75332,
#      23754,
#      46622,
#      159011,
#      583,
#      63667,
#      66918,
#      150029,
#      63685,
#      31396,
#      644,
#      182977,
#      27130,
#      211865,
#      158991,
#      142441,
#      63708,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      118201,
#      2213,
#      210815,
#      127689,
#      66631,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_KBN1X81ZW:9',
#     'guid': 'tag:reuters.com,2019:newsml_KBN1X81ZW',
#     'version': 9,
#     'dateCreated': 1572411775000,
#     'slug': 'US-MIDEAST-CRISIS-BAGHDADI-YAZIDIS',
#     'author': 'By Raya Jalabi',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': "For Yazidis, Baghdadi's death 'doesn't feel like justice yet'",
#     'mediaType': 'T',
#     'priority': 4,
#     'geography': ['IQ', 'SY', 'IND', 'TR', 'US'],
#     'channels': ['FES376'],
#     'indexTimestamp': 1572411777888,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['OUSWDM', 'OCATPM', 'RTRFLN', 'OUSTPM', 'OUS12'],
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'internalReceivedDate': 1572411777888,
#     'channelIds': [176647,
#      176649,
#      56668,
#      62030,
#      150629,
#      65819,
#      65820,
#      61422,
#      24218,
#      24217,
#      25532]},
#    {'id': 'tag:reuters.com,2019:newsml_L5N26G34E:636821721',
#     'guid': 'tag:reuters.com,2019:newsml_L5N26G34E',
#     'version': 636821721,
#     'dateCreated': 1572397200000,
#     'slug': 'INDIA-LAND/MILITARY (FEATURE, PIX)',
#     'author': 'By Ashutosh Sharma, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': "FEATURE-India's increasing defences eat away at farmland along border with Pakistan",
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['IN', 'PK'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572397203776,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572397203776,
#     'channelIds': [37917,
#      144993,
#      626,
#      159003,
#      31386,
#      63692,
#      22321,
#      131355,
#      55889,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      150029,
#      27212,
#      31390,
#      63685,
#      644,
#      182977,
#      211865,
#      142441,
#      635,
#      22283,
#      159015,
#      41078,
#      23926,
#      118201,
#      26788,
#      2213,
#      127689,
#      66631,
#      191903,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_KBN1X823F:6',
#     'guid': 'tag:reuters.com,2019:newsml_KBN1X823F',
#     'version': 6,
#     'dateCreated': 1572390693000,
#     'slug': 'US-USA-IMMIGRATION',
#     'author': 'By Julio-Cesar Chavez',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Border arrests hit 11-year high, U.S. seeks to expedite deportations',
#     'mediaType': 'T',
#     'priority': 4,
#     'geography': ['IND', 'US', 'MX'],
#     'channels': ['FES376'],
#     'indexTimestamp': 1572390696088,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['OUSWDM',
#      'OUSPOM',
#      'OUSDNM',
#      'LCOM',
#      'OUSTPM',
#      'RTRFLN',
#      'OUS12'],
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'internalReceivedDate': 1572390696088,
#     'channelIds': [176647,
#      176649,
#      56668,
#      65819,
#      24206,
#      65811,
#      176643,
#      65820,
#      65815,
#      24218,
#      24217,
#      25532,
#      133467,
#      24212,
#      136807,
#      176637,
#      68139]},
#    {'id': 'tag:reuters.com,2019:newsml_L2N27E0XS:392535204',
#     'guid': 'tag:reuters.com,2019:newsml_L2N27E0XS',
#     'version': 392535204,
#     'dateCreated': 1572390527000,
#     'slug': 'USA-IMMIGRATION/ (UPDATE 3, PIX)',
#     'author': 'By Julio-Cesar Chavez',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'UPDATE 3-Border arrests hit 11-year high, U.S. seeks to expedite deportations',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['US', 'MX'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572390530458,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:U'],
#     'internalReceivedDate': 1572390530458,
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      176417,
#      63692,
#      22321,
#      154815,
#      75332,
#      159011,
#      583,
#      63667,
#      150029,
#      63685,
#      644,
#      182977,
#      211865,
#      20483,
#      142441,
#      635,
#      22283,
#      159015,
#      41078,
#      31374,
#      118201,
#      2213,
#      127689,
#      176419,
#      634,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_L2N27E1G3:1173410049',
#     'guid': 'tag:reuters.com,2019:newsml_L2N27E1G3',
#     'version': 1173410049,
#     'dateCreated': 1572390228000,
#     'slug': 'USA-TRAFFICKING/',
#     'author': 'By Ellen Wulfhorst, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Focused look at human trafficking could reveal better data, top US official says',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['KE', 'US'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572390231414,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1572390231414,
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      154815,
#      23929,
#      75332,
#      23754,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      63685,
#      644,
#      182977,
#      170643,
#      23751,
#      211865,
#      20483,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      23927,
#      41078,
#      118201,
#      2213,
#      127689,
#      170645,
#      634,
#      191903,
#      127687,
#      63655,
#      70595]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27E58U:800427946',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27E58U',
#     'version': 800427946,
#     'dateCreated': 1572365750000,
#     'slug': 'MIDEAST-CRISIS/BAGHDADI-YAZIDIS (PIX)',
#     'author': 'By Raya Jalabi',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'For Yazidis, Baghdadi\'s death "doesn\'t feel like justice yet"',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['IQ', 'SY', 'TR', 'US'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572365755126,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'DNP',
#      'M',
#      'GNS',
#      'GFN',
#      'O',
#      'CSA',
#      'GBN',
#      'RNP',
#      'U',
#      'REULB',
#      'RBN',
#      'PSC',
#      'LBY',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'AFA'],
#     'signal': ['prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'sic:XBSUM',
#      'edStat:N'],
#     'internalReceivedDate': 1572365755126,
#     'channelIds': [76637,
#      63683,
#      37917,
#      144993,
#      626,
#      159003,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      22800,
#      57606,
#      154815,
#      31407,
#      63660,
#      180027,
#      63675,
#      75332,
#      23754,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      76633,
#      63685,
#      644,
#      63646,
#      27199,
#      44352,
#      211865,
#      180029,
#      158991,
#      142441,
#      610,
#      635,
#      62870,
#      589,
#      22283,
#      159015,
#      23927,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      23926,
#      661,
#      565,
#      601,
#      118201,
#      63669,
#      2213,
#      127689,
#      176419,
#      634,
#      34327,
#      191903,
#      564,
#      127687,
#      180031,
#      63655,
#      70595,
#      30480,
#      588,
#      63709,
#      554]},
#    {'id': 'tag:reuters.com,2019:newsml_KBN1X81N6:4',
#     'guid': 'tag:reuters.com,2019:newsml_KBN1X81N6',
#     'version': 4,
#     'dateCreated': 1572363491000,
#     'slug': 'UK-BRITAIN-BODIES-BROTHERS',
#     'author': 'By Michael Holden',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Police hunt for brothers from Northern Ireland over truck deaths',
#     'mediaType': 'T',
#     'priority': 4,
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG', 'IND'],
#     'channels': ['TRn222'],
#     'indexTimestamp': 1572363494133,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['OUKDNM', 'NOINWDM', 'ORTAK', 'OUKTPM', 'ORTOA'],
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'internalReceivedDate': 1572363494133,
#     'channelIds': [22849,
#      25437,
#      176625,
#      23274,
#      153071,
#      176461,
#      25411,
#      24237,
#      24242,
#      176629]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27E4ZS:761182222',
#     'guid': 'tag:reuters.com,2019:newsml_L8N27E4ZS',
#     'version': 761182222,
#     'dateCreated': 1572363332000,
#     'slug': 'BRITAIN-BODIES/BROTHERS (UPDATE 3, PIX)',
#     'author': 'By Michael Holden',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'UPDATE 3-Police hunt for brothers from Northern Ireland over truck deaths',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572363338386,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'DNP',
#      'M',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'SI',
#      'Z',
#      'REULB',
#      'RBN',
#      'PSC',
#      'LBY',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'UKI',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'AFA'],
#     'signal': ['prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U',
#      'sic:XBSUM'],
#     'internalReceivedDate': 1572363338386,
#     'channelIds': [76637,
#      63683,
#      37917,
#      26786,
#      144993,
#      626,
#      68932,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      57606,
#      154815,
#      180027,
#      63675,
#      63699,
#      75332,
#      23754,
#      46622,
#      159011,
#      583,
#      63667,
#      164607,
#      199799,
#      167293,
#      150029,
#      22802,
#      76633,
#      63685,
#      31396,
#      644,
#      76630,
#      63646,
#      27216,
#      27199,
#      44352,
#      211865,
#      180029,
#      158991,
#      142441,
#      63708,
#      672,
#      195519,
#      610,
#      648,
#      635,
#      62870,
#      22283,
#      159015,
#      141803,
#      23927,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      23926,
#      661,
#      565,
#      601,
#      118201,
#      31397,
#      63669,
#      22307,
#      2213,
#      63643,
#      127689,
#      170645,
#      176419,
#      634,
#      31377,
#      68945,
#      34327,
#      191903,
#      564,
#      127687,
#      22807,
#      180031,
#      63655,
#      70595,
#      30480,
#      63709,
#      554]},
#    {'id': 'tag:reuters.com,2019:newsml_L9N26H01O:1510505850',
#     'guid': 'tag:reuters.com,2019:newsml_L9N26H01O',
#     'version': 1510505850,
#     'dateCreated': 1572356851000,
#     'slug': 'BRITAIN-BODIES/BROTHERS (URGENT)',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'UK police hunting two brothers from N.Ireland over truck deaths',
#     'mediaType': 'T',
#     'priority': 2,
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572356855996,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['NAT',
#      'PTD',
#      'C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'DNP',
#      'M',
#      'ABN',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'SI',
#      'Z',
#      'REULB',
#      'RBN',
#      'PSC',
#      'LBY',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'UKI',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'PEN',
#      'PCM',
#      'AFA'],
#     'signal': ['sig:update',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'internalReceivedDate': 1572356855996,
#     'channelIds': [76637,
#      63683,
#      37917,
#      26786,
#      619,
#      144993,
#      626,
#      68932,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      623,
#      57606,
#      154815,
#      180027,
#      63675,
#      63699,
#      75332,
#      46622,
#      605,
#      159011,
#      583,
#      63667,
#      539,
#      164607,
#      167293,
#      150029,
#      22802,
#      76633,
#      63685,
#      31396,
#      644,
#      621,
#      76630,
#      63646,
#      27216,
#      27199,
#      44352,
#      211865,
#      180029,
#      158991,
#      20483,
#      142441,
#      63708,
#      672,
#      195519,
#      610,
#      648,
#      635,
#      62870,
#      22283,
#      159015,
#      141803,
#      23927,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      23926,
#      661,
#      565,
#      601,
#      118201,
#      31397,
#      63669,
#      22307,
#      2213,
#      63643,
#      127689,
#      170645,
#      63676,
#      176419,
#      634,
#      31377,
#      68945,
#      34327,
#      191903,
#      564,
#      127687,
#      22807,
#      180031,
#      63655,
#      70595,
#      30480,
#      63709,
#      554]},
#    {'id': 'tag:reuters.com,2019:newsml_MT1ALTL9N26H01O4:327056005',
#     'guid': 'tag:reuters.com,2019:newsml_MT1ALTL9N26H01O4',
#     'version': 327056005,
#     'dateCreated': 1572356422000,
#     'slug': 'ESSEX POLICE SAY BROTHERS FROM NORTHERN IRELAND ARE WANTED ON SU',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'ESSEX POLICE SAY BROTHERS FROM NORTHERN IRELAND ARE WANTED ON SUSPICION OF MANSLAUGHTER AND HUMAN TRAFFICKING',
#     'mediaType': 'T',
#     'priority': 1,
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1572356426600,
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'destination': ['ZZ',
#      'C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'M',
#      'ABN',
#      'GNS',
#      'O',
#      'CSA',
#      'U',
#      'Z',
#      'REULB',
#      'RBN',
#      'LBY',
#      'ZD',
#      'SOF',
#      'RWS',
#      'UCDPTEST',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'REUEB',
#      'AFA'],
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'internalReceivedDate': 1572356426600,
#     'channelIds': [37917,
#      626,
#      176417,
#      34325,
#      63398,
#      63411,
#      57606,
#      63393,
#      63438,
#      63424,
#      583,
#      539,
#      584,
#      63447,
#      63446,
#      644,
#      211865,
#      20483,
#      142441,
#      672,
#      610,
#      63436,
#      561,
#      661,
#      565,
#      63462,
#      601,
#      118201,
#      2213,
#      127689,
#      176419,
#      634,
#      63430,
#      34327,
#      62871,
#      127687,
#      142045,
#      554]},
#    {'id': 'tag:reuters.com,2019:newsml_L8N27E3FV:924489769',
# ...
#     'language': 'en',
#     'headline': "Gay men seen dying from AIDS due to Africa's homophobic laws",
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['KE'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1570487402340,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'AFN',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1570487402340,
#     'channelIds': [542,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      55889,
#      154815,
#      70666,
#      75332,
#      29598,
#      63633,
#      159011,
#      583,
#      63667,
#      150029,
#      204119,
#      63685,
#      644,
#      182977,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      41078,
#      63496,
#      118201,
#      2213,
#      47543,
#      66631,
#      191903,
#      564,
#      63655,
#      70595]},
#    {'id': 'tag:reuters.com,2019:newsml_L2N26S1CC:193938379',
#     'guid': 'tag:reuters.com,2019:newsml_L2N26S1CC',
#     'version': 193938379,
#     'dateCreated': 1570481942000,
#     'slug': 'COLOMBIA-TRAFFICKING/MIGRANTS',
#     'author': 'By Anastasia Moloney, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Colombia makes sex trafficking arrests along desert border with Venezuela',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['CO', 'VE'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1570481944800,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1570481944800,
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      22800,
#      154815,
#      162061,
#      75332,
#      23754,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      153673,
#      63685,
#      644,
#      182977,
#      170643,
#      211865,
#      20483,
#      142441,
#      635,
#      22283,
#      159015,
#      141803,
#      23927,
#      31373,
#      41078,
#      118201,
#      2213,
#      634,
#      191903,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_L5N26S4MI:1935839058',
#     'guid': 'tag:reuters.com,2019:newsml_L5N26S4MI',
#     'version': 1935839058,
#     'dateCreated': 1570470729000,
#     'slug': 'GLOBAL-RIGHTS/STATELESS (UPDATE 1 PIX)',
#     'author': 'By Emma Batha, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'UPDATE 1-Film star Cate Blanchett backs drive to end plight of 10 mln stateless',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['IR', 'KG', 'CO', 'IN', 'SY', 'VE'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1570470736206,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1570470736206,
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      31386,
#      63692,
#      22321,
#      131355,
#      55889,
#      154815,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      150029,
#      63685,
#      644,
#      182977,
#      170643,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      31373,
#      41078,
#      31410,
#      118201,
#      2213,
#      127689,
#      634,
#      66631,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_L2N26B1LN:368104729',
#     'guid': 'tag:reuters.com,2019:newsml_L2N26B1LN',
#     'version': 368104729,
#     'dateCreated': 1570443442000,
#     'slug': 'NIGER-CLIMATE-CHANGE/FAMILYPLANNING (FEATURE, PIX)',
#     'author': 'By Sebastien Malo, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'FEATURE-Fewer children, fewer climate risks? Niger ponders a controversial option',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['NE'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1570443446727,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'AFN',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1570443446727,
#     'channelIds': [63683,
#      542,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      22800,
#      55889,
#      70666,
#      211145,
#      22791,
#      75332,
#      29598,
#      23754,
#      63633,
#      159011,
#      583,
#      63667,
#      150029,
#      27212,
#      204119,
#      63685,
#      644,
#      182977,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      41078,
#      118201,
#      26788,
#      2213,
#      634,
#      66631,
#      564,
#      63655,
#      70595]},
#    {'id': 'tag:reuters.com,2019:newsml_L5N25F2KY:1359185985',
#     'guid': 'tag:reuters.com,2019:newsml_L5N25F2KY',
#     'version': 1359185985,
#     'dateCreated': 1570440135000,
#     'slug': 'MALAYSIA-MIGRANTS/RIGHTS (PIX)',
#     'author': 'By Beh Lih Yi, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': "Malaysia's first 'ethical' job agency targets modern slavery",
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['PH', 'BD', 'ID', 'CN', 'MY'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1570440139777,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'SNS',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1570440139777,
#     'channelIds': [63683,
#      37917,
#      26786,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      55889,
#      27217,
#      154815,
#      23325,
#      162061,
#      75332,
#      651,
#      159011,
#      583,
#      31391,
#      63667,
#      150029,
#      31376,
#      26789,
#      63685,
#      63698,
#      644,
#      182977,
#      170643,
#      27216,
#      211865,
#      158991,
#      142441,
#      195519,
#      635,
#      22283,
#      159015,
#      41078,
#      31388,
#      118201,
#      31387,
#      139745,
#      2213,
#      127689,
#      634,
#      187915,
#      31377,
#      31378,
#      22635,
#      66631,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_L5N26L6P0:1672772159',
#     'guid': 'tag:reuters.com,2019:newsml_L5N26L6P0',
#     'version': 1672772159,
#     'dateCreated': 1570402861000,
#     'slug': 'GLOBAL-RIGHTS/STATELESS-BRAZIL (INTERVIEW, PIX)',
#     'author': 'By Emma Batha, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'INTERVIEW-I found a country, but lost my brother - stateless activist',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['BR', 'CH', 'SY', 'LB'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1570402866755,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1570402866755,
#     'channelIds': [63683,
#      37917,
#      626,
#      63692,
#      22321,
#      131355,
#      55889,
#      75332,
#      583,
#      63685,
#      644,
#      142441,
#      22283,
#      41078,
#      118201,
#      2213,
#      127689,
#      634,
#      66631,
#      127687,
#      63655,
#      70595]},
#    {'id': 'tag:reuters.com,2019:newsml_L5N26L5OC:181343249',
#     'guid': 'tag:reuters.com,2019:newsml_L5N26L5OC',
#     'version': 181343249,
#     'dateCreated': 1570402861000,
#     'slug': 'GLOBAL-RIGHTS/STATELESS (FACTBOX)',
#     'author': 'By Emma Batha, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': "FACTBOX -Where are the world's stateless people?",
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['MM',
#      'EE',
#      'NP',
#      'BD',
#      'RU',
#      'SY',
#      'CI',
#      'IQ',
#      'LV',
#      'DO',
#      'KW',
#      'CO',
#      'TH'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1570402868208,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1570402868208,
#     'channelIds': [63683,
#      37917,
#      626,
#      63692,
#      22321,
#      131355,
#      55889,
#      75332,
#      583,
#      63685,
#      644,
#      211865,
#      142441,
#      22283,
#      41078,
#      118201,
#      2213,
#      127689,
#      634,
#      66631,
#      127687,
#      63655,
#      70595]},
#    {'id': 'tag:reuters.com,2019:newsml_L5N26J0C0:1741901242',
#     'guid': 'tag:reuters.com,2019:newsml_L5N26J0C0',
#     'version': 1741901242,
#     'dateCreated': 1570402860000,
#     'slug': 'GLOBAL-RIGHTS/STATELESS',
#     'author': 'By Emma Batha, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Film star Cate Blanchett backs drive to end plight of 10 mln stateless',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['IR', 'KG', 'CO', 'IN', 'SY', 'VE'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1570402865703,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1570402865703,
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      31386,
#      63692,
#      22321,
#      131355,
#      55889,
#      154815,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      150029,
#      63685,
#      644,
#      182977,
#      170643,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      31373,
#      41078,
#      31410,
#      118201,
#      2213,
#      127689,
#      634,
#      66631,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_L3N26L3SY:1062418178',
#     'guid': 'tag:reuters.com,2019:newsml_L3N26L3SY',
#     'version': 1062418178,
#     'dateCreated': 1570316460000,
#     'slug': 'GLOBAL-RIGHTS/STATELESS-INDIA (FEATURE, PIX)',
#     'author': 'By Anuradha Nagaraj, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': "FEATURE-What's in a name? India's citizenship drive hits women hardest",
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['IN'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1570316463155,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'SNS',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1570316463155,
#     'channelIds': [37917,
#      144993,
#      626,
#      159003,
#      31386,
#      63692,
#      22321,
#      22800,
#      55889,
#      75332,
#      23754,
#      651,
#      159011,
#      583,
#      63667,
#      150029,
#      63685,
#      63698,
#      644,
#      182977,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      159015,
#      41078,
#      118201,
#      2213,
#      66631,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480]},
#    {'id': 'tag:reuters.com,2019:newsml_L5N26370I:336501807',
#     'guid': 'tag:reuters.com,2019:newsml_L5N26370I',
#     'version': 336501807,
#     'dateCreated': 1570257446000,
#     'slug': 'KENYA-WATER/CLIMATE-CHANGE (CORRECTED, FEATURE, PIX)',
#     'author': 'By Kagondu Njagi, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'CORRECTED-FEATURE-Kenyan farmers mix tradition with tech to protect drying Mara River',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['KE'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1570257449381,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT',
#      'pmt:text',
#      'edStat:C',
#      'sig:correction',
#      'source:ids'],
#     'internalReceivedDate': 1570257449381,
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      55889,
#      211145,
#      22791,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      150029,
#      204119,
#      63685,
#      644,
#      182977,
#      27130,
#      27216,
#      211865,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      41078,
#      118201,
#      2213,
#      26791,
#      634,
#      66631,
#      63655,
#      70595]},
#    {'id': 'tag:reuters.com,2019:newsml_L5N26P3IG:751146665',
#     'guid': 'tag:reuters.com,2019:newsml_L5N26P3IG',
#     'version': 751146665,
#     'dateCreated': 1570205802000,
#     'slug': 'BANGLADESH-TRAFFICKING/BRUNEI',
#     'author': 'By Naimul Karim, Thomson Reuters Foundation',
#     'source': 'Thomson Reuters',
#     'language': 'en',
#     'headline': 'Bangladesh asks Brunei to deport suspects in human trafficking ring',
#     'mediaType': 'T',
#     'priority': 3,
#     'geography': ['BN', 'BD'],
#     'channels': ['STK567'],
#     'indexTimestamp': 1570205805082,
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'SNS',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'internalReceivedDate': 1570205805082,
#     'channelIds': [37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      55889,
#      154815,
#      75332,
#      651,
#      159011,
#      583,
#      63667,
#      150029,
#      31376,
#      63685,
#      63698,
#      644,
#      182977,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      159015,
#      41078,
#      118201,
#      2213,
#      66631,
#      564,
#      63655,
#      70595,
#      30480]}],
#   'numFound': 171,
#   'size': 171,
#   'start': 0,
#   'mediaTypeBreakdownPercent': {'T': 100, 'P': 0, 'C': 0, 'V': 0, 'G': 0},
#   'status': {'code': 20,
#    'errors': [{'faultcode': 1002,
#      'faultstring': 'Start date has been modified to 2019-10-04T12:34:22.065Z'},
#     {'faultcode': 1001, 'faultstring': 'Limit was adjusted to 300'}]}}}

# %%
# convert json to pandas dataframe

results_info = t_results['results']['result']
t_results_df = pd.DataFrame(results_info)
print(t_results_df.shape)
t_results_df.head()
# Out:
# (171, 20)
#                                                   id  \
# 0    tag:reuters.com,2019:newsml_L3N27I00W:391219080
# 1    tag:reuters.com,2019:newsml_L8N27H5Q0:447177668
# 2            tag:reuters.com,2019:newsml_KBN1XB3XS:6
# 3   tag:reuters.com,2019:newsml_L8N27H2WN:1498332260
# 4  tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2:1...
#
#                                            guid     version    dateCreated  \
# 0         tag:reuters.com,2019:newsml_L3N27I00W   391219080  1572659257000
# 1         tag:reuters.com,2019:newsml_L8N27H5Q0   447177668  1572646886000
# 2         tag:reuters.com,2019:newsml_KBN1XB3XS           6  1572640591000
# 3         tag:reuters.com,2019:newsml_L8N27H2WN  1498332260  1572640534000
# 4  tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2  1099731627  1572615643000
#
#                                                 slug           source  \
# 0                             BRITAIN-BODIES/VIETNAM  Thomson Reuters
# 1                     BRAZIL-HUMAN TRAFFICKING/ (TV)  Thomson Reuters
# 2                                  UK-BRITAIN-BODIES  Thomson Reuters
# 3                BRITAIN-BODIES/ (UPDATE 3, PIX, TV)  Thomson Reuters
# 4  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...  Thomson Reuters
#
#   language                                           headline mediaType  \
# 0       en  Vietnam says human traffickers must be strictl...         T
# 1       en  Brazil police arrest man said to be one of wor...         T
# 2       en  Second man charged over UK truck deaths, victi...         T
# 3       en  UPDATE 3-Second man charged over UK truck deat...         T
# 4       en  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...         T
#
#    priority                  geography  channels  indexTimestamp  \
# 0         3       [VN, BE, GB, CN, BG]  [STK567]   1572659267216
# 1         3   [BR, BD, MX, AF, IN, US]  [STK567]   1572646890383
# 2         4  [VN, GB, CN, IE, BG, IND]  [TRn222]   1572640594477
# 3         3       [VN, GB, CN, IE, BG]  [STK567]   1572640540811
# 4         1       [VN, GB, CN, IE, BG]  [STK567]   1572615647562
#
#   contributorId contributorName  \
# 0          RTRS         Reuters
# 1          RTRS         Reuters
# 2          RTRS         Reuters
# 3          RTRS         Reuters
# 4          RTRS         Reuters
#
#                                          destination  \
# 0  [ZZ, C, MTL, D, E, GRO, G, DNP, M, GNS, O, CSA...
# 1  [PSC, LBY, G, DNP, GNS, PGE, RWS, CSA, UCDPTES...
# 2  [NOINSKM, OUKDNM, NOINWDM, ORTAK, OUKWDM, OUKT...
# 3  [PSC, LBY, G, DNP, GNS, PGE, RWS, CSA, UCDPTES...
# 4  [ZZ, C, MTL, D, E, GRO, G, M, ABN, GNS, O, CSA...
#
#                                               signal  internalReceivedDate  \
# 0       [prodId:TXT, pmt:text, source:ids, edStat:N]         1572659267216
# 1       [prodId:TXT, pmt:text, source:ids, edStat:N]         1572646890383
# 2  [var:itemMod, prodId:TXT, pmt:text, source:ids...         1572640594477
# 3  [prodId:TXT, pmt:text, source:ids, edStat:U, s...         1572640540811
# 4  [var:itemMod, prodId:TXT, pmt:text, source:ids...         1572615647562
#
#                                           channelIds              author
# 0  [76637, 63683, 37917, 26786, 144993, 626, 6893...                 NaN
# 1  [63683, 37917, 144993, 626, 159003, 176417, 31...                 NaN
# 2  [23276, 83733, 22849, 25437, 176625, 23274, 14...  By Amanda Ferguson
# 3  [63683, 37917, 144993, 626, 159003, 662, 17641...  By Amanda Ferguson
# 4  [37917, 626, 176417, 34325, 63398, 63411, 5760...                 NaN

# %%
# get articles by id

def query_by_id(t_id):
    url = f'http://rmb.reuters.com/rmd/rest/json/item?id={t_id}&token={authToken}&format=json'
    response = requests.get(url)
    return json.loads(response.text)

by_id = t_results_df.id.apply(lambda x: query_by_id(x))

# convert to pandas dataframe
text_df = pd.DataFrame.from_dict(by_id.tolist())
text_df.columns
# Out:
# Index(['destination', 'productlabel', 'representationtype', 'copyrightholder',
#        'copyrightnotice', 'credit', 'profile', 'signal', 'firstcreated',
#        'headline', 'language', 'mimetype', 'slug', 'caption', 'subject',
#        'subjectlocation', 'altid', 'type', 'urgency', 'uri', 'usn', 'version',
#        'versioncreated', 'versionedguid', 'wordcount', 'body_xhtml',
#        'renditions', 'byline', 'dateline', 'derivedfrom', 'located', 'source'],
#       dtype='object')

# %%
# parse fulltext

def parse_html(string):
    soup = BeautifulSoup(string, 'html.parser')    

    texts = []
    for i in soup.find_all('p'):
        texts.append(i.get_text())
        
    return '\n'.join(texts)

text_df['parsed_text'] = text_df.body_xhtml.apply(lambda x: parse_html(x))

# %%
print(text_df.columns)

text_df.head()
# Out:
# Index(['destination', 'productlabel', 'representationtype', 'copyrightholder',
#        'copyrightnotice', 'credit', 'profile', 'signal', 'firstcreated',
#        'headline', 'language', 'mimetype', 'slug', 'caption', 'subject',
#        'subjectlocation', 'altid', 'type', 'urgency', 'uri', 'usn', 'version',
#        'versioncreated', 'versionedguid', 'wordcount', 'body_xhtml',
#        'renditions', 'byline', 'dateline', 'derivedfrom', 'located', 'source',
#        'parsed_text'],
#       dtype='object')
#                                          destination productlabel  \
# 0  [CSA, SI, ZZ, ZD, LBY, REULB, G, RAST, SOF, M,...         text
# 1  [CSA, LBY, REULB, G, RAST, PGE, RNP, AFA, PSC,...         text
# 2  [OUKTPM, ORTOA, OUKDNM, OUKWDM, NOINWDM, NOINS...         text
# 3  [CSA, SI, LBY, REULB, G, RAST, PGE, RNP, UKI, ...         text
# 4  [CSA, ZZ, ZD, LBY, REULB, G, RAST, SOF, M, Z, ...         text
#
#   representationtype  copyrightholder  \
# 0           complete  Thomson Reuters
# 1           complete  Thomson Reuters
# 2           complete  Thomson Reuters
# 3           complete  Thomson Reuters
# 4           complete  Thomson Reuters
#
#                                      copyrightnotice   credit   profile  \
# 0  (c) Copyright Thomson Reuters 2019. Click For ...  Reuters  SNI-Text
# 1  (c) Copyright Thomson Reuters 2019. Click For ...  Reuters  SNI-Text
# 2  (c) Copyright Thomson Reuters 2019. Click For ...  Reuters  SNI-Text
# 3  (c) Copyright Thomson Reuters 2019. Click For ...  Reuters  SNI-Text
# 4  (c) Copyright Thomson Reuters 2019. Click For ...  Reuters  SNI-Text
#
#                                           signal              firstcreated  \
# 0               [edStat:N, prodId:TXT, pmt:text]  2019-11-02T01:47:37.000Z
# 1               [edStat:N, prodId:TXT, pmt:text]  2019-11-01T22:21:26.000Z
# 2  [edStat:U, prodId:TXT, pmt:text, var:itemMod]  2019-11-01T11:05:29.000Z
# 3    [edStat:U, prodId:TXT, pmt:text, sic:XBSUM]  2019-11-01T11:45:27.000Z
# 4  [edStat:N, prodId:TXT, pmt:text, var:itemMod]  2019-11-01T13:40:43.000Z
#
#                                             headline  ...  \
# 0  Vietnam says human traffickers must be strictl...  ...
# 1  Brazil police arrest man said to be one of wor...  ...
# 2  Second man charged over UK truck deaths, victi...  ...
# 3  UPDATE 3-Second man charged over UK truck deat...  ...
# 4  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...  ...
#
#                                        versionedguid wordcount  \
# 0    tag:reuters.com,2019:newsml_L3N27I00W:391219080       226
# 1    tag:reuters.com,2019:newsml_L8N27H5Q0:447177668       346
# 2            tag:reuters.com,2019:newsml_KBN1XB3XS:6       450
# 3   tag:reuters.com,2019:newsml_L8N27H2WN:1498332260       499
# 4  tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2:1...        21
#
#                                           body_xhtml  \
# 0                <p>Nov 2 (Reuters) - Vietnam sai...
# 1                <p>SAO PAULO, Nov 1 (Reuters) - ...
# 2                <p>By Amanda Ferguson</p>\n     ...
# 3                <p>* Thirty-nine bodies were fou...
# 4                <p>NORTHERN IRISH MAN IS CHARGED...
#
#                                           renditions              byline  \
# 0  [{'mimetype': 'application/vnd.iptc.g2.newsite...                 NaN
# 1  [{'mimetype': 'application/vnd.iptc.g2.newsite...                 NaN
# 2  [{'mimetype': 'application/vnd.iptc.g2.newsite...  By Amanda Ferguson
# 3  [{'mimetype': 'application/vnd.iptc.g2.newsite...  By Amanda Ferguson
# 4  [{'mimetype': 'application/vnd.iptc.g2.newsite...                 NaN
#
#                         dateline                              derivedfrom  \
# 0                            NaN                                      NaN
# 1                            NaN                                      NaN
# 2  2019-11-01 20:36:31 GMT+00:00  [tag:reuters.com,2019:newsml_L8N27H2WN]
# 3                            NaN                                      NaN
# 4                            NaN  [tag:reuters.com,2019:newsml_L9N26H01T]
#
#             located                                     source  \
# 0               NaN                                        NaN
# 1               NaN                                        NaN
# 2  Bangalore, India  {'code': 'NS:RTRS', 'literal': 'Reuters'}
# 3               NaN                                        NaN
# 4               NaN                                        NaN
#
#                                          parsed_text
# 0  Nov 2 (Reuters) - Vietnam said on Saturday tha...
# 1  SAO PAULO, Nov 1 (Reuters) - Brazilian federal...
# 2  By Amanda Ferguson\nBELFAST (Reuters) - A seco...
# 3  * Thirty-nine bodies were found in a truck on ...
# 4  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...
#
# [5 rows x 33 columns]

# %%
# only keep relevant columns

relevant_columns = ['firstcreated', 'headline', 'language',  'slug', 'caption',
    'urgency', 'uri', 'usn', 'version', 'versioncreated',
       'versionedguid', 'wordcount', 'body_xhtml', 'dateline', 'parsed_text']
text_df = text_df[relevant_columns]


t_results_df_relcols = ['id', 'guid', 'dateCreated', 'geography']
t_results_df_rel = t_results_df[t_results_df_relcols]

# %%
# add information from t_results_df (table returned by customized query string)
# merge tables into one

text_df['guid'] = text_df['uri']
all_api_df = t_results_df_rel.merge(text_df, on='guid')

all_api_df.head()
# Out:
#                                                   id  \
# 0    tag:reuters.com,2019:newsml_L3N27I00W:391219080
# 1    tag:reuters.com,2019:newsml_L8N27H5Q0:447177668
# 2            tag:reuters.com,2019:newsml_KBN1XB3XS:6
# 3   tag:reuters.com,2019:newsml_L8N27H2WN:1498332260
# 4  tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2:1...
#
#                                            guid    dateCreated  \
# 0         tag:reuters.com,2019:newsml_L3N27I00W  1572659257000
# 1         tag:reuters.com,2019:newsml_L8N27H5Q0  1572646886000
# 2         tag:reuters.com,2019:newsml_KBN1XB3XS  1572640591000
# 3         tag:reuters.com,2019:newsml_L8N27H2WN  1572640534000
# 4  tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2  1572615643000
#
#                    geography              firstcreated  \
# 0       [VN, BE, GB, CN, BG]  2019-11-02T01:47:37.000Z
# 1   [BR, BD, MX, AF, IN, US]  2019-11-01T22:21:26.000Z
# 2  [VN, GB, CN, IE, BG, IND]  2019-11-01T11:05:29.000Z
# 3       [VN, GB, CN, IE, BG]  2019-11-01T11:45:27.000Z
# 4       [VN, GB, CN, IE, BG]  2019-11-01T13:40:43.000Z
#
#                                             headline language  \
# 0  Vietnam says human traffickers must be strictl...       en
# 1  Brazil police arrest man said to be one of wor...       en
# 2  Second man charged over UK truck deaths, victi...    en-GB
# 3  UPDATE 3-Second man charged over UK truck deat...       en
# 4  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...       en
#
#                                                 slug  \
# 0                             BRITAIN-BODIES/VIETNAM
# 1                     BRAZIL-HUMAN TRAFFICKING/ (TV)
# 2                                  UK-BRITAIN-BODIES
# 3                BRITAIN-BODIES/ (UPDATE 3, PIX, TV)
# 4  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...
#
#                                              caption  urgency  \
# 0  BRITAIN-BODIES/VIETNAM:Vietnam says human traf...        3
# 1  BRAZIL-HUMAN TRAFFICKING/ (TV):Brazil police a...        3
# 2  UK-BRITAIN-BODIES:Second man charged over UK t...        4
# 3  BRITAIN-BODIES/ (UPDATE 3, PIX, TV):UPDATE 3-S...        3
# 4  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...        1
#
#                                             uri               usn     version  \
# 0         tag:reuters.com,2019:newsml_L3N27I00W         L3N27I00W   391219080
# 1         tag:reuters.com,2019:newsml_L8N27H5Q0         L8N27H5Q0   447177668
# 2         tag:reuters.com,2019:newsml_KBN1XB3XS         KBN1XB3XS           6
# 3         tag:reuters.com,2019:newsml_L8N27H2WN         L8N27H2WN  1498332260
# 4  tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2  MT1ALTL9N26H01T2  1099731627
#
#              versioncreated  \
# 0  2019-11-02T01:47:37.000Z
# 1  2019-11-01T22:21:26.000Z
# 2  2019-11-01T20:36:31.000Z
# 3  2019-11-01T20:35:34.000Z
# 4  2019-11-01T13:40:43.000Z
#
#                                        versionedguid  wordcount  \
# 0    tag:reuters.com,2019:newsml_L3N27I00W:391219080        226
# 1    tag:reuters.com,2019:newsml_L8N27H5Q0:447177668        346
# 2            tag:reuters.com,2019:newsml_KBN1XB3XS:6        450
# 3   tag:reuters.com,2019:newsml_L8N27H2WN:1498332260        499
# 4  tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2:1...         21
#
#                                           body_xhtml  \
# 0                <p>Nov 2 (Reuters) - Vietnam sai...
# 1                <p>SAO PAULO, Nov 1 (Reuters) - ...
# 2                <p>By Amanda Ferguson</p>\n     ...
# 3                <p>* Thirty-nine bodies were fou...
# 4                <p>NORTHERN IRISH MAN IS CHARGED...
#
#                         dateline  \
# 0                            NaN
# 1                            NaN
# 2  2019-11-01 20:36:31 GMT+00:00
# 3                            NaN
# 4                            NaN
#
#                                          parsed_text
# 0  Nov 2 (Reuters) - Vietnam said on Saturday tha...
# 1  SAO PAULO, Nov 1 (Reuters) - Brazilian federal...
# 2  By Amanda Ferguson\nBELFAST (Reuters) - A seco...
# 3  * Thirty-nine bodies were found in a truck on ...
# 4  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...

# %%
## add long version of countries
all_api_df['countries_long'] = all_api_df.geography.fillna('').apply(lambda x: ','.join([cc_mapping_reverse.get(i) for i in x if i in cc_mapping_reverse]))
all_api_df['countries_long_newversion'] = all_api_df.geography.fillna('').apply(lambda x: ','.join([cc_mapping_reverse_normalized.get(i) for i in x if i in cc_mapping_reverse_normalized]))

all_api_df.head()
# Out:
#                                                   id  \
# 0    tag:reuters.com,2019:newsml_L3N27I00W:391219080
# 1    tag:reuters.com,2019:newsml_L8N27H5Q0:447177668
# 2            tag:reuters.com,2019:newsml_KBN1XB3XS:6
# 3   tag:reuters.com,2019:newsml_L8N27H2WN:1498332260
# 4  tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2:1...
#
#                                            guid    dateCreated  \
# 0         tag:reuters.com,2019:newsml_L3N27I00W  1572659257000
# 1         tag:reuters.com,2019:newsml_L8N27H5Q0  1572646886000
# 2         tag:reuters.com,2019:newsml_KBN1XB3XS  1572640591000
# 3         tag:reuters.com,2019:newsml_L8N27H2WN  1572640534000
# 4  tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2  1572615643000
#
#                    geography              firstcreated  \
# 0       [VN, BE, GB, CN, BG]  2019-11-02T01:47:37.000Z
# 1   [BR, BD, MX, AF, IN, US]  2019-11-01T22:21:26.000Z
# 2  [VN, GB, CN, IE, BG, IND]  2019-11-01T11:05:29.000Z
# 3       [VN, GB, CN, IE, BG]  2019-11-01T11:45:27.000Z
# 4       [VN, GB, CN, IE, BG]  2019-11-01T13:40:43.000Z
#
#                                             headline language  \
# 0  Vietnam says human traffickers must be strictl...       en
# 1  Brazil police arrest man said to be one of wor...       en
# 2  Second man charged over UK truck deaths, victi...    en-GB
# 3  UPDATE 3-Second man charged over UK truck deat...       en
# 4  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...       en
#
#                                                 slug  \
# 0                             BRITAIN-BODIES/VIETNAM
# 1                     BRAZIL-HUMAN TRAFFICKING/ (TV)
# 2                                  UK-BRITAIN-BODIES
# 3                BRITAIN-BODIES/ (UPDATE 3, PIX, TV)
# 4  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...
#
#                                              caption  urgency  ...  \
# 0  BRITAIN-BODIES/VIETNAM:Vietnam says human traf...        3  ...
# 1  BRAZIL-HUMAN TRAFFICKING/ (TV):Brazil police a...        3  ...
# 2  UK-BRITAIN-BODIES:Second man charged over UK t...        4  ...
# 3  BRITAIN-BODIES/ (UPDATE 3, PIX, TV):UPDATE 3-S...        3  ...
# 4  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...        1  ...
#
#                 usn     version            versioncreated  \
# 0         L3N27I00W   391219080  2019-11-02T01:47:37.000Z
# 1         L8N27H5Q0   447177668  2019-11-01T22:21:26.000Z
# 2         KBN1XB3XS           6  2019-11-01T20:36:31.000Z
# 3         L8N27H2WN  1498332260  2019-11-01T20:35:34.000Z
# 4  MT1ALTL9N26H01T2  1099731627  2019-11-01T13:40:43.000Z
#
#                                        versionedguid wordcount  \
# 0    tag:reuters.com,2019:newsml_L3N27I00W:391219080       226
# 1    tag:reuters.com,2019:newsml_L8N27H5Q0:447177668       346
# 2            tag:reuters.com,2019:newsml_KBN1XB3XS:6       450
# 3   tag:reuters.com,2019:newsml_L8N27H2WN:1498332260       499
# 4  tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2:1...        21
#
#                                           body_xhtml  \
# 0                <p>Nov 2 (Reuters) - Vietnam sai...
# 1                <p>SAO PAULO, Nov 1 (Reuters) - ...
# 2                <p>By Amanda Ferguson</p>\n     ...
# 3                <p>* Thirty-nine bodies were fou...
# 4                <p>NORTHERN IRISH MAN IS CHARGED...
#
#                         dateline  \
# 0                            NaN
# 1                            NaN
# 2  2019-11-01 20:36:31 GMT+00:00
# 3                            NaN
# 4                            NaN
#
#                                          parsed_text  \
# 0  Nov 2 (Reuters) - Vietnam said on Saturday tha...
# 1  SAO PAULO, Nov 1 (Reuters) - Brazilian federal...
# 2  By Amanda Ferguson\nBELFAST (Reuters) - A seco...
# 3  * Thirty-nine bodies were found in a truck on ...
# 4  NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTE...
#
#                                countries_long  \
# 0                               Vietnam,China
# 1  Brazil,Bangladesh,Mexico,Afghanistan,India
# 2                               Vietnam,China
# 3                               Vietnam,China
# 4                               Vietnam,China
#
#                     countries_long_newversion
# 0                               Vietnam,China
# 1  Brazil,Bangladesh,Mexico,Afghanistan,India
# 2                               Vietnam,China
# 3                               Vietnam,China
# 4                               Vietnam,China
#
# [5 rows x 21 columns]

# %%
# save table with API results 

all_api_df.to_csv('../Data/TR_API_files/TR_API_results.tsv', sep='\t', header=True, index=None)

# %%
# Extra: Overview of country code distribution in results

countries_lists = t_results_df_rel.geography.fillna('')
country_dist = pd.Series([i for sublist in countries_lists for i in sublist]).value_counts()

country_dist_df = pd.DataFrame(country_dist).reset_index()

country_dist_df.columns = ['country_code', 'observed_count']

country_dist_df.to_csv('../Data/TR_API_files/country_code_dist_articles.tsv', sep='\t', header=True, index=None)
