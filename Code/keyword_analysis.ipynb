# %%
import pandas as pd
import nltk
import spacy
import pickle

import pprint

from spacy.lang.en import English
from nltk.stem.wordnet import WordNetLemmatizer

from collections import defaultdict

import gensim
from gensim.models import LdaModel

from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## Term-frequency Inverse Document Frequency Analysis
# ### Aim: extract keywords per article

# %%
# configuration of pre-processing tools

nlp = spacy.load('en_core_web_sm')
parser = English()

en_stop = set(nltk.corpus.stopwords.words('english'))
en_stop.add('pron') # append spacy abbreviation for pronoun to stopwords
en_stop.add('')

# %%
# load data (output from TR API)

api_output_path = '../Data/TR_API_files/TR_API_results.tsv'
api_output = pd.read_csv(api_output_path, sep='\t')
api_output.head()
# Out:
#                                                  id  \
# 0   tag:reuters.com,2019:newsml_L3N27I00W:391219080
# 1   tag:reuters.com,2019:newsml_L8N27H5Q0:447177668
# 2           tag:reuters.com,2019:newsml_KBN1XB3XS:6
# 3  tag:reuters.com,2019:newsml_L8N27H2WN:1498332260
# 4   tag:reuters.com,2019:newsml_L8N27H0YP:739041794
#
#                                     guid    dateCreated  \
# 0  tag:reuters.com,2019:newsml_L3N27I00W  1572659257000
# 1  tag:reuters.com,2019:newsml_L8N27H5Q0  1572646886000
# 2  tag:reuters.com,2019:newsml_KBN1XB3XS  1572640591000
# 3  tag:reuters.com,2019:newsml_L8N27H2WN  1572640534000
# 4  tag:reuters.com,2019:newsml_L8N27H0YP  1572627800000
#
#                                geography              firstcreated  \
# 0         ['VN', 'BE', 'GB', 'CN', 'BG']  2019-11-02T01:47:37.000Z
# 1   ['BR', 'BD', 'MX', 'AF', 'IN', 'US']  2019-11-01T22:21:26.000Z
# 2  ['VN', 'GB', 'CN', 'IE', 'BG', 'IND']  2019-11-01T11:05:29.000Z
# 3         ['VN', 'GB', 'CN', 'IE', 'BG']  2019-11-01T11:45:27.000Z
# 4                           ['LB', 'IL']  2019-11-01T07:17:26.000Z
#
#                                             headline language  \
# 0  Vietnam says human traffickers must be strictl...       en
# 1  Brazil police arrest man said to be one of wor...       en
# 2  Second man charged over UK truck deaths, victi...    en-GB
# 3  UPDATE 3-Second man charged over UK truck deat...       en
# 4  UPDATE 6-Hezbollah: Lebanon's next government ...       en
#
#                                     slug  \
# 0                 BRITAIN-BODIES/VIETNAM
# 1         BRAZIL-HUMAN TRAFFICKING/ (TV)
# 2                      UK-BRITAIN-BODIES
# 3    BRITAIN-BODIES/ (UPDATE 3, PIX, TV)
# 4  LEBANON-PROTESTS/ (UPDATE 6, PIX, TV)
#
#                                              caption  urgency  ...        usn  \
# 0  BRITAIN-BODIES/VIETNAM:Vietnam says human traf...        3  ...  L3N27I00W
# 1  BRAZIL-HUMAN TRAFFICKING/ (TV):Brazil police a...        3  ...  L8N27H5Q0
# 2  UK-BRITAIN-BODIES:Second man charged over UK t...        4  ...  KBN1XB3XS
# 3  BRITAIN-BODIES/ (UPDATE 3, PIX, TV):UPDATE 3-S...        3  ...  L8N27H2WN
# 4  LEBANON-PROTESTS/ (UPDATE 6, PIX, TV):UPDATE 6...        3  ...  L8N27H0YP
#
#       version            versioncreated  \
# 0   391219080  2019-11-02T01:47:37.000Z
# 1   447177668  2019-11-01T22:21:26.000Z
# 2           6  2019-11-01T20:36:31.000Z
# 3  1498332260  2019-11-01T20:35:34.000Z
# 4   739041794  2019-11-01T17:03:20.000Z
#
#                                       versionedguid wordcount  \
# 0   tag:reuters.com,2019:newsml_L3N27I00W:391219080       226
# 1   tag:reuters.com,2019:newsml_L8N27H5Q0:447177668       346
# 2           tag:reuters.com,2019:newsml_KBN1XB3XS:6       450
# 3  tag:reuters.com,2019:newsml_L8N27H2WN:1498332260       499
# 4   tag:reuters.com,2019:newsml_L8N27H0YP:739041794       722
#
#                                           body_xhtml  \
# 0                <p>Nov 2 (Reuters) - Vietnam sai...
# 1                <p>SAO PAULO, Nov 1 (Reuters) - ...
# 2                <p>By Amanda Ferguson</p>\n     ...
# 3                <p>* Thirty-nine bodies were fou...
# 4                <p>* Hezbollah urges forming new...
#
#                         dateline  \
# 0                            NaN
# 1                            NaN
# 2  2019-11-01 20:36:31 GMT+00:00
# 3                            NaN
# 4                            NaN
#
#                                          parsed_text  \
# 0  Nov 2 (Reuters) - Vietnam said on Saturday tha...
# 1  SAO PAULO, Nov 1 (Reuters) - Brazilian federal...
# 2  By Amanda Ferguson\nBELFAST (Reuters) - A seco...
# 3  * Thirty-nine bodies were found in a truck on ...
# 4  * Hezbollah urges forming new cabinet quickly\...
#
#                                countries_long  \
# 0                               Vietnam,China
# 1  Brazil,Bangladesh,Mexico,Afghanistan,India
# 2                               Vietnam,China
# 3                               Vietnam,China
# 4                                     Lebanon
#
#                     countries_long_newversion
# 0                               Vietnam,China
# 1  Brazil,Bangladesh,Mexico,Afghanistan,India
# 2                               Vietnam,China
# 3                               Vietnam,China
# 4                                     Lebanon
#
# [5 rows x 21 columns]

# %%
text_collection = api_output[['guid', 'parsed_text']].copy()

# %%
# get list of documents

text_collection['document'] = text_collection.parsed_text.apply(lambda x: ' '.join(x.split('\n')))

text_collection = text_collection.drop('parsed_text', axis=1)

text_collection
# Out:
#                                       guid  \
# 0    tag:reuters.com,2019:newsml_L3N27I00W
# 1    tag:reuters.com,2019:newsml_L8N27H5Q0
# 2    tag:reuters.com,2019:newsml_KBN1XB3XS
# 3    tag:reuters.com,2019:newsml_L8N27H2WN
# 4    tag:reuters.com,2019:newsml_L8N27H0YP
# ..                                     ...
# 272  tag:reuters.com,2019:newsml_KCN1WK0HB
# 273  tag:reuters.com,2019:newsml_L5N26P39K
# 274  tag:reuters.com,2019:newsml_L5N26370I
# 275  tag:reuters.com,2019:newsml_L5N26P2ZA
# 276  tag:reuters.com,2019:newsml_L5N26P3IG
#
#                                               document
# 0    Nov 2 (Reuters) - Vietnam said on Saturday tha...
# 1    SAO PAULO, Nov 1 (Reuters) - Brazilian federal...
# 2    By Amanda Ferguson BELFAST (Reuters) - A secon...
# 3    * Thirty-nine bodies were found in a truck on ...
# 4    * Hezbollah urges forming new cabinet quickly ...
# ..                                                 ...
# 272  By John Davison BAGHDAD (Reuters) - Dozens of ...
# 273  (Updates with new death toll) By John Davison ...
# 274  (Clarifies description of software tool) By Ka...
# 275  (Updates with German interior minister, Greek ...
# 276  By Naimul Karim DHAKA, Oct 4 (Thomson Reuters ...
#
# [277 rows x 2 columns]

# %%
# pre-process with spacy

text_collection['nlp'] = text_collection.document.apply(lambda x: nlp(x))

# %%
# add lemmatized version

text_collection['lemmas'] = text_collection.nlp.apply(lambda x: [t.lemma_.lower() for t in x])

# %%
# count lemma frequencies and only keep that appear more than once
# remove stopwords

frequency = defaultdict(int)
for text in text_collection.lemmas:
    for lemma in text:
        frequency[lemma] += 1
        

text_collection['processed_lemmas'] = text_collection.lemmas.apply(lambda x: [lemma for lemma in x if frequency[lemma] > 1 and not lemma in en_stop])
text_collection.processed_lemmas

# %%
# add bigrams and trigrams to docs (only ones that appear 20 times or more)

docs = text_collection.processed_lemmas.tolist()

bigram = gensim.models.Phrases(docs, min_count=5)
for idx in range(len(docs)):
    for token in bigram[docs[idx]]:
        if '_' in token:
            # token is a bigram, add to document.
            docs[idx].append(token)
            
            
text_collection['docs_ngrams'] = docs

# %%
# calculate tf-idf

corpus = text_collection['docs_ngrams'].apply(lambda x: ' '.join(x)).tolist()

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(corpus)

feature_names = vectorizer.get_feature_names()

# %%
# top number of terms identified through tf-idf

n_max = 10

tf_idf_docscores = list()

for doc_idx in range(len(corpus)):
    print('\n')
    
    feature_index = tfidf_matrix[doc_idx,:].nonzero()[1]
    tfidf_scores = zip(feature_index, [tfidf_matrix[doc_idx, x] for x in feature_index])
    
    tfidf_per_lemma = sorted([(feature_names[i], s) for (i, s) in tfidf_scores], key=lambda x: x[1], reverse=True)
    
    
    for lemma, score in tfidf_per_lemma[:n_max]:
        print(lemma, score)
        
        
    tf_idf_docscores.append(tfidf_per_lemma[:n_max])

# %%
text_collection['keywords'] = tf_idf_docscores

text_collection.head()

# %%
keyword_output = text_collection[['guid', 'document', 'keywords']].copy()

keyword_output['keywords'] = keyword_output.keywords.apply(lambda x: '; '.join([f'{i[0]}: {i[1]}' for i in x]))

keyword_output.head()

# %%
keyword_output.to_csv('../Data/TR_API_files/keywords_per_article.tsv', sep='\t', index=None)
